# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, train_test_split

# %% [markdown]
# <h1 align="center" style="color:yellow">Data Loading</h1>

# %% [markdown]
# Since we don't have genetical_risk column for rest of the group. So, we can add a dummy column name "Genetical_Risk" and set default value to 0

# %%
df = pd.read_excel("premiums_rest.xlsx")
df.head(3)
# Out:
#    Age  Gender     Region Marital_status  Number Of Dependants BMI_Category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
#
#   Smoking_Status Employment_Status Income_Level  Income_Lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
#
#        Medical History Insurance_Plan  Annual_Premium_Amount
# 0             Diabetes         Bronze                   9053
# 1             Diabetes         Bronze                  16339
# 2  High blood pressure         Silver                  18164

# %%
df["Genetical_Risk"] = 0

# %%
df.shape
# Out:
# (29904, 14)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Region', 'Marital_status', 'Number Of Dependants',
#        'BMI_Category', 'Smoking_Status', 'Employment_Status', 'Income_Level',
#        'Income_Lakhs', 'Medical History', 'Insurance_Plan',
#        'Annual_Premium_Amount', 'Genetical_Risk'],
#       dtype='object')

# %%
df.columns = df.columns.str.replace(" ", "_").str.lower()
df.columns
# Out:
# Index(['age', 'gender', 'region', 'marital_status', 'number_of_dependants',
#        'bmi_category', 'smoking_status', 'employment_status', 'income_level',
#        'income_lakhs', 'medical_history', 'insurance_plan',
#        'annual_premium_amount', 'genetical_risk'],
#       dtype='object')

# %% [markdown]
# <h1 align="center" style="color:yellow">Exploratory Data Analysis & Data Cleaning</h1>

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Handling NA values</h3>

# %%
df.isna().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           9
# employment_status        1
# income_level             9
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# genetical_risk           0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# age                      0
# gender                   0
# region                   0
# marital_status           0
# number_of_dependants     0
# bmi_category             0
# smoking_status           0
# employment_status        0
# income_level             0
# income_lakhs             0
# medical_history          0
# insurance_plan           0
# annual_premium_amount    0
# genetical_risk           0
# dtype: int64

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Handled Duplicates</h3>

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  29886.000000          29886.000000  29886.000000
# mean      43.396105              2.379910     23.364184
# std       13.412657              1.431201     24.740339
# min       26.000000             -3.000000      1.000000
# 25%       34.000000              1.000000      7.000000
# 50%       42.000000              3.000000     17.000000
# 75%       52.000000              3.000000     32.000000
# max      356.000000              5.000000    930.000000
#
#        annual_premium_amount  genetical_risk
# count           29886.000000         29886.0
# mean            20892.303821             0.0
# std              6936.813440             0.0
# min              3625.000000             0.0
# 25%             15697.250000             0.0
# 50%             20489.000000             0.0
# 75%             26360.000000             0.0
# max             43471.000000             0.0

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Data Cleaning: number_of_dependants</h3>

# %%
df[df.number_of_dependants < 0].shape
# Out:
# (50, 14)

# %%
df[df.number_of_dependants < 0]['number_of_dependants'].unique()
# Out:
# array([-1, -3])

# %% [markdown]
# We can see some negative values in number_of_dependants. We can replace them with positive numbers

# %%
df['number_of_dependants'] = abs(df['number_of_dependants'])
df['number_of_dependants'].describe()
# Out:
# count    29886.000000
# mean         2.385933
# std          1.421137
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          3.000000
# max          5.000000
# Name: number_of_dependants, dtype: float64

# %% [markdown]
# ## 1. Numeric Columns

# %% [markdown]
# ### Univariate Analysis: Numeric Columns

# %% [markdown]
# #### Box plots for numeric columns

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns

# %% [markdown]
# Boxplot is good for checking outliers in numeric columns

# %%
for column in numeric_columns:
    sns.boxplot(data=df, x=column)
    plt.show()

# %% [markdown]
# ### Outlier Treatment: Age Column

# %%
df[df.age > 100]['age'].unique()
# Out:
# array([224, 124, 136, 203, 356])

# %%
df1 = df[df.age <= 100].copy()
df1.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  29828.000000          29828.000000  29828.000000
# mean      43.095380              2.387790     23.371530
# std       11.041991              1.420641     24.751262
# min       26.000000              0.000000      1.000000
# 25%       34.000000              1.000000      7.000000
# 50%       42.000000              3.000000     17.000000
# 75%       52.000000              3.000000     32.000000
# max       72.000000              5.000000    930.000000
#
#        annual_premium_amount  genetical_risk
# count           29828.000000         29828.0
# mean            20901.900563             0.0
# std              6928.457636             0.0
# min              6538.000000             0.0
# 25%             15706.000000             0.0
# 50%             20496.000000             0.0
# 75%             26361.000000             0.0
# max             43471.000000             0.0

# %% [markdown]
# ### Outlier Treatment: Income Column

# %%
df1.income_lakhs.quantile([0.25, 0.75])
# Out:
# 0.25     7.0
# 0.75    32.0
# Name: income_lakhs, dtype: float64

# %%
def get_iqr_bounds(col):
    Q1, Q3 = col.quantile([0.25, 0.75])
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q3 + 1.5*IQR
    return lower_bound, upper_bound

# %%
lower, upper = get_iqr_bounds(df1.income_lakhs)
lower, upper
# Out:
# (-30.5, 69.5)

# %%
df1[df1.income_lakhs>upper].shape
# Out:
# (2090, 14)

# %% [markdown]
# There are many legitimate records that we will get rid of if we use IQR bounds method. Hence after discussion with business we decided to use a simple quantile bound

# %%
quantile_threshold = df1.income_lakhs.quantile(0.999)
quantile_threshold
# Out:
# 100.0

# %%
df1[df1.income_lakhs>quantile_threshold].shape
# Out:
# (6, 14)

# %%
df2 = df1[df1.income_lakhs <= quantile_threshold].copy()
df2.describe()
# Out:
#                 age  number_of_dependants  income_lakhs  \
# count  29822.000000          29822.000000  29822.000000
# mean      43.094896              2.387734     23.226343
# std       11.042430              1.420644     22.455408
# min       26.000000              0.000000      1.000000
# 25%       34.000000              1.000000      7.000000
# 50%       42.000000              3.000000     17.000000
# 75%       52.000000              3.000000     32.000000
# max       72.000000              5.000000    100.000000
#
#        annual_premium_amount  genetical_risk
# count           29822.000000         29822.0
# mean            20900.689223             0.0
# std              6928.192115             0.0
# min              6538.000000             0.0
# 25%             15705.250000             0.0
# 50%             20495.500000             0.0
# 75%             26360.000000             0.0
# max             43471.000000             0.0

# %%
# sns.histplot(data=df2, x=df2['income_lakhs'], kde=True)
# plt.show()

# %%
for col in numeric_columns:
    sns.histplot(data=df2, x=df2[col],kde=True)
    plt.show()

# %%
fig, axs = plt.subplots(nrows=2, ncols=3, figsize=(15, 10))  # Adjust the size to ensure plots are not squeezed

for i, column in enumerate(numeric_columns):
    # Locating the correct subplot using integer division and modulus
    ax = axs[i // 3, i % 3]  # Row index is i//3, column index is i%3
    sns.histplot(df2[column], kde=True, ax=ax)
    ax.set_title(column)

# If the last subplot axis is unused, you can turn it off
if len(numeric_columns) % 3 != 0:
    for j in range(len(numeric_columns), 6):  # This will disable any unused subplots
        axs.flat[j].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Bivariate Analysis: Numeric Columns

# %%
sns.scatterplot(data=df2, x=df2['age'], y=df2['annual_premium_amount'])
plt.show()

# %%
for col in numeric_columns:
    sns.scatterplot(data=df2, x=df2[col], y=df2['annual_premium_amount'])
    plt.show()

# %%
numeric_features = ['age', 'income_lakhs', 'number_of_dependants', 'genetical_risk']

fig, axes = plt.subplots(nrows=1, ncols=len(numeric_features), figsize=(18, 6))  # Adjust figure size as necessary

for ax, column in zip(axes, numeric_features):
    sns.scatterplot(x=df2[column], y=df2['annual_premium_amount'], ax=ax)
    ax.set_title(f'{column} vs. Annual Premium Amount')
    ax.set_xlabel(column)
    ax.set_ylabel('Annual Premium Amount')

plt.tight_layout()  # Adjust layout
plt.show()

# %%
df.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   56    Male  Northeast        Married                     3      Obesity
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4     Occasional     Self-Employed    10L - 25L            14
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk
# ...

# %% [markdown]
# ## 2. Categorical Columns

# %%
categorical_cols = df2.select_dtypes(exclude=['int64', 'float64']).columns
for col in categorical_cols:
    print(col, ":", df2[col].unique())
# Out:
# gender : ['Male' 'Female']
# region : ['Northwest' 'Southeast' 'Northeast' 'Southwest']
# marital_status : ['Unmarried' 'Married']
# bmi_category : ['Normal' 'Obesity' 'Overweight' 'Underweight']
# smoking_status : ['No Smoking' 'Regular' 'Occasional' 'Does Not Smoke' 'Not Smoking'
#  'Smoking=0']
# employment_status : ['Salaried' 'Self-Employed' 'Freelancer']
# income_level : ['<10L' '10L - 25L' '> 40L' '25L - 40L']
# medical_history : ['Diabetes' 'High blood pressure' 'No Disease'
#  'Diabetes & High blood pressure' 'Thyroid' 'Heart disease'
#  'High blood pressure & Heart disease' 'Diabetes & Thyroid'
#  'Diabetes & Heart disease']
# insurance_plan : ['Bronze' 'Silver' 'Gold']

# %%
df2.smoking_status.replace({
    'Smoking=0': 'No Smoking',
    'Does Not Smoke': 'No Smoking',
    'Not Smoking': 'No Smoking'
}, inplace=True)
df2.smoking_status.unique()
# Out:
# array(['No Smoking', 'Regular', 'Occasional'], dtype=object)

# %% [markdown]
# ### Univariate Analysis

# %%
df2.head(2)
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
#
#   smoking_status employment_status income_level  income_lakhs medical_history  \
# 0     No Smoking          Salaried         <10L             6        Diabetes
# 1        Regular          Salaried         <10L             6        Diabetes
#
#   insurance_plan  annual_premium_amount  genetical_risk
# 0         Bronze                   9053               0
# 1         Bronze                  16339               0

# %%
pct_count = df2['gender'].value_counts(normalize=True)*100
pct_count
# Out:
# gender
# Male      54.912481
# Female    45.087519
# Name: proportion, dtype: float64

# %%
sns.barplot(x=pct_count.index, y=pct_count.values)
# Out:
# <Axes: xlabel='gender'>

# %%
fig, axes = plt.subplots(3, 3, figsize=(18, 18))  # Adjust figure size as necessary
axes = axes.flatten()  # Flatten the 2D array of axes into 1D for easier iteration

for ax, column in zip(axes, categorical_cols):
    # Calculate the percentage distribution of each category
    category_counts = df2[column].value_counts(normalize=True) * 100  # normalize=True gives the relative frequencies
    
    # Plotting the distribution using barplot
    sns.barplot(x=category_counts.index, y=category_counts.values, ax=ax)
    ax.set_title(f'Percentage Distribution of {column}')
    ax.set_ylabel('Percentage of Policyholders (%)')
    ax.set_xlabel(column)  # Set xlabel to the column name for clarity

plt.tight_layout()  # Adjusts plot parameters for better fit in the figure window
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
# Cross-tabulation of gender and smoking status
crosstab = pd.crosstab(index=df2['income_level'], columns=df2['insurance_plan'])
crosstab
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L          799  3554    4354
# 25L - 40L          301  2631    3142
# <10L              6054   527    4341
# > 40L              214  3287     618

# %%
# Cross-tabulation of gender and smoking status
crosstab = pd.crosstab(index= df2['income_level'], columns= df2['insurance_plan'])
print(crosstab)

# Plotting the crosstab
crosstab.plot(kind='bar', stacked=True)
plt.title('Income vs Plan')
plt.xticks(rotation = 0)
plt.ylabel('Count')
plt.show()
# Out:
# insurance_plan  Bronze  Gold  Silver
# income_level
# 10L - 25L          799  3554    4354
# 25L - 40L          301  2631    3142
# <10L              6054   527    4341
# > 40L              214  3287     618

# %%
sns.heatmap(crosstab, annot=True, fmt="d")
plt.title('Heatmap of Income vs Plan')
plt.show()

# %% [markdown]
# <h1 align="center" style="color:yellow">Feature Engineering</h1>

# %%
df2.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   56    Male  Northeast        Married                     3      Obesity
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4     Occasional     Self-Employed    10L - 25L            14
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk
# ...

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Calculate Risk Score</h3>

# %%
df2.medical_history.unique()
# Out:
# array(['Diabetes', 'High blood pressure', 'No Disease',
#        'Diabetes & High blood pressure', 'Thyroid', 'Heart disease',
#        'High blood pressure & Heart disease', 'Diabetes & Thyroid',
#        'Diabetes & Heart disease'], dtype=object)

# %%
# Define the risk scores for each condition
risk_scores = {
    "diabetes": 6,
    "heart disease": 8,
    "high blood pressure":6,
    "thyroid": 5,
    "no disease": 0,
    "none":0
}

# %%
df2[['disease1', 'disease2']] = df2['medical_history'].str.split(" & ", expand=True).apply(lambda x: x.str.lower())
df2.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   56    Male  Northeast        Married                     3      Obesity
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4     Occasional     Self-Employed    10L - 25L            14
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk  \
# ...

# %%
df2.disease2.isna().sum()
# Out:
# 26058

# %%
df2['disease1'].fillna('none', inplace=True)
df2['disease2'].fillna('none', inplace=True)
df2['total_risk_score'] = 0
for disease in ['disease1', 'disease2']:
    df2['total_risk_score'] += df2[disease].map(risk_scores)

max_score = df2['total_risk_score'].max()
min_score = df2['total_risk_score'].min()
df2['normalized_risk_score'] = (df2['total_risk_score'] - min_score) / (max_score - min_score)
df2.head()
# Out:
#    age  gender     region marital_status  number_of_dependants bmi_category  \
# 0   26    Male  Northwest      Unmarried                     0       Normal
# 1   29  Female  Southeast        Married                     2      Obesity
# 2   49  Female  Northeast        Married                     2       Normal
# 3   30  Female  Southeast        Married                     3       Normal
# 4   56    Male  Northeast        Married                     3      Obesity
#
#   smoking_status employment_status income_level  income_lakhs  \
# 0     No Smoking          Salaried         <10L             6
# 1        Regular          Salaried         <10L             6
# 2     No Smoking     Self-Employed    10L - 25L            20
# 3     No Smoking          Salaried        > 40L            77
# 4     Occasional     Self-Employed    10L - 25L            14
#
#        medical_history insurance_plan  annual_premium_amount  genetical_risk  \
# ...

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Encode Text Columns</h3>

# %%
df2.insurance_plan.unique()
# Out:
# array(['Bronze', 'Silver', 'Gold'], dtype=object)

# %%
df2['insurance_plan'] = df2['insurance_plan'].map({'Bronze':1, 'Silver':2, 'Gold':3})
df2.insurance_plan.unique()
# Out:
# array([1, 2, 3])

# %%
df2.income_level.unique()
# Out:
# array(['<10L', '10L - 25L', '> 40L', '25L - 40L'], dtype=object)

# %%
df2['income_level'] = df2['income_level'].map({'<10L':1, '10L - 25L': 2, '25L - 40L':3, '> 40L':4})
df2.income_level.unique()
# Out:
# array([1, 2, 4, 3])

# %%
nominal_cols = ['gender', 'region', 'marital_status', 'bmi_category', 'smoking_status', 'employment_status']
df3 = pd.get_dummies(data=df2, columns=nominal_cols, drop_first=True, dtype=int)
df3.head()
# Out:
#    age  number_of_dependants  income_level  income_lakhs      medical_history  \
# 0   26                     0             1             6             Diabetes
# 1   29                     2             1             6             Diabetes
# 2   49                     2             2            20  High blood pressure
# 3   30                     3             4            77           No Disease
# 4   56                     3             2            14             Diabetes
#
#    insurance_plan  annual_premium_amount  genetical_risk             disease1  \
# 0               1                   9053               0             diabetes
# 1               1                  16339               0             diabetes
# 2               2                  18164               0  high blood pressure
# 3               3                  20303               0           no disease
# 4               1                  15610               0             diabetes
#
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29822 entries, 0 to 29903
# Data columns (total 24 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              29822 non-null  int64
#  1   number_of_dependants             29822 non-null  int64
#  2   income_level                     29822 non-null  int64
#  3   income_lakhs                     29822 non-null  int64
#  4   medical_history                  29822 non-null  object
#  5   insurance_plan                   29822 non-null  int64
#  6   annual_premium_amount            29822 non-null  int64
#  7   genetical_risk                   29822 non-null  int64
#  8   disease1                         29822 non-null  object
#  9   disease2                         29822 non-null  object
#  10  total_risk_score                 29822 non-null  int64
#  11  normalized_risk_score            29822 non-null  float64
# ...

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Feature Selection</h3>

# %%
df4 = df3.drop(['medical_history','disease1', 'disease2', 'total_risk_score'], axis=1)
df4.head(3)
# Out:
#    age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0   26                     0             1             6               1
# 1   29                     2             1             6               1
# 2   49                     2             2            20               2
#
#    annual_premium_amount  genetical_risk  normalized_risk_score  gender_Male  \
# 0                   9053               0               0.428571            1
# 1                  16339               0               0.428571            0
# 2                  18164               0               0.428571            0
#
#    region_Northwest  region_Southeast  region_Southwest  \
# 0                 1                 0                 0
# 1                 0                 1                 0
# 2                 0                 0                 0
#
#    marital_status_Unmarried  bmi_category_Obesity  bmi_category_Overweight  \
# ...

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Calculate VIF for Multicolinearity</h3>

# %%
df4.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_level', 'income_lakhs',
#        'insurance_plan', 'annual_premium_amount', 'genetical_risk',
#        'normalized_risk_score', 'gender_Male', 'region_Northwest',
#        'region_Southeast', 'region_Southwest', 'marital_status_Unmarried',
#        'bmi_category_Obesity', 'bmi_category_Overweight',
#        'bmi_category_Underweight', 'smoking_status_Occasional',
#        'smoking_status_Regular', 'employment_status_Salaried',
#        'employment_status_Self-Employed'],
#       dtype='object')

# %%
cm = df4.corr()

plt.figure(figsize=(20,12))
sns.heatmap(cm, annot=True)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df4.head(5)
# Out:
#    age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0   26                     0             1             6               1
# 1   29                     2             1             6               1
# 2   49                     2             2            20               2
# 3   30                     3             4            77               3
# 4   56                     3             2            14               1
#
#    annual_premium_amount  genetical_risk  normalized_risk_score  gender_Male  \
# 0                   9053               0               0.428571            1
# 1                  16339               0               0.428571            0
# 2                  18164               0               0.428571            0
# 3                  20303               0               0.000000            0
# 4                  15610               0               0.428571            1
#
#    region_Northwest  region_Southeast  region_Southwest  \
# ...

# %%
X = df4.drop('annual_premium_amount', axis=1)
y = df4['annual_premium_amount']
cols_to_scale = ['age','number_of_dependants', 'income_level',  'income_lakhs', 'insurance_plan', 'genetical_risk']
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X[cols_to_scale] = scaler.fit_transform(X[cols_to_scale])
X.head(4)
# Out:
#         age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0  0.000000                   0.0      0.000000      0.050505             0.0
# 1  0.065217                   0.4      0.000000      0.050505             0.0
# 2  0.500000                   0.4      0.333333      0.191919             0.5
# 3  0.086957                   0.6      1.000000      0.767677             1.0
#
#    genetical_risk  normalized_risk_score  gender_Male  region_Northwest  \
# 0             0.0               0.428571            1                 1
# 1             0.0               0.428571            0                 0
# 2             0.0               0.428571            0                 0
# 3             0.0               0.000000            0                 0
#
#    region_Southeast  region_Southwest  marital_status_Unmarried  \
# 0                 0                 0                         1
# 1                 1                 0                         0
# ...

# %%
X.describe()
# Out:
#                 age  number_of_dependants  income_level  income_lakhs  \
# count  29822.000000          29822.000000  29822.000000  29822.000000
# mean       0.371628              0.477547      0.371225      0.224509
# std        0.240053              0.284129      0.351111      0.226822
# min        0.000000              0.000000      0.000000      0.000000
# 25%        0.173913              0.200000      0.000000      0.060606
# 50%        0.347826              0.600000      0.333333      0.161616
# 75%        0.565217              0.600000      0.666667      0.313131
# max        1.000000              1.000000      1.000000      1.000000
#
#        insurance_plan  genetical_risk  normalized_risk_score   gender_Male  \
# count    29822.000000         29822.0           29822.000000  29822.000000
# mean         0.544112             0.0               0.426373      0.549125
# std          0.379009             0.0               0.240084      0.497589
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Variable'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values, i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X)
# Out:
#                            Variable        VIF
# 0                               age   3.921783
# 1              number_of_dependants   6.278938
# 2                      income_level  13.890522
# 3                      income_lakhs  11.185596
# 4                    insurance_plan   5.271297
# 5                    genetical_risk        NaN
# 6             normalized_risk_score   3.810619
# 7                       gender_Male   2.599098
# 8                  region_Northwest   2.123965
# 9                  region_Southeast   2.980842
# 10                 region_Southwest   2.710097
# 11         marital_status_Unmarried   2.346288
# 12             bmi_category_Obesity   1.478248
# 13          bmi_category_Overweight   1.735085
# 14         bmi_category_Underweight   1.255611
# 15        smoking_status_Occasional   1.378264
# 16           smoking_status_Regular   2.131638
# 17       employment_status_Salaried   3.177473
# 18  employment_status_Self-Employed   2.871687

# %% [markdown]
# Anytime when VIF > 10 then we have to drop those columns

# %%
calculate_vif(X.drop('income_level', axis=1))
# Out:
#                            Variable       VIF
# 0                               age  3.863055
# 1              number_of_dependants  6.278147
# 2                      income_lakhs  2.678102
# 3                    insurance_plan  4.574625
# 4                    genetical_risk       NaN
# 5             normalized_risk_score  3.808345
# 6                       gender_Male  2.591439
# 7                  region_Northwest  2.123277
# 8                  region_Southeast  2.979899
# 9                  region_Southwest  2.708641
# 10         marital_status_Unmarried  2.345757
# 11             bmi_category_Obesity  1.477906
# 12          bmi_category_Overweight  1.734646
# 13         bmi_category_Underweight  1.255270
# 14        smoking_status_Occasional  1.378237
# 15           smoking_status_Regular  2.131406
# 16       employment_status_Salaried  3.169218
# 17  employment_status_Self-Employed  2.866611

# %%
# we will drop income_lakhs due to high VIF value
X_reduced = X.drop('income_level', axis="columns")
X_reduced.head()
# Out:
#         age  number_of_dependants  income_lakhs  insurance_plan  \
# 0  0.000000                   0.0      0.050505             0.0
# 1  0.065217                   0.4      0.050505             0.0
# 2  0.500000                   0.4      0.191919             0.5
# 3  0.086957                   0.6      0.767677             1.0
# 4  0.652174                   0.6      0.131313             0.0
#
#    genetical_risk  normalized_risk_score  gender_Male  region_Northwest  \
# 0             0.0               0.428571            1                 1
# 1             0.0               0.428571            0                 0
# 2             0.0               0.428571            0                 0
# 3             0.0               0.000000            0                 0
# 4             0.0               0.428571            1                 0
#
#    region_Southeast  region_Southwest  marital_status_Unmarried  \
# 0                 0                 0                         1
# ...

# %% [markdown]
# <h1 align="center" style="color:yellow">Model Training</h1>

# %%
X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.30, random_state=10)

# shape of the X_train, X_test, y_train, y_test features
print("X train: ",X_train.shape)
print("X test: ",X_test.shape)
print("y train: ",y_train.shape)
print("y test: ",y_test.shape)
# Out:
# X train:  (20875, 18)
# X test:  (8947, 18)
# y train:  (20875,)
# y test:  (8947,)

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Training Linear Regression Model</h3>

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
train_score = model_lr.score(X_train, y_train)
test_score = model_lr.score(X_test, y_test)
train_score, test_score
# Out:
# (0.9534163989489616, 0.9538448451629948)

# %% [markdown]
# In above we check score for both train and test and we got same train score as well as test score, why we do this because, Sometimes what happens is, if model is Overfitting the train score will be higher but test score will be lower.

# %%
y_pred = model_lr.predict(X_test)

mse_lr = mean_squared_error(y_test, y_pred)
rmse_lr = np.sqrt(mse_lr)
print("Linear Regression ==> MSE: ", mse_lr, "RMSE: ", rmse_lr)
# Out:
# Linear Regression ==> MSE:  2183844.3603124553 RMSE:  1477.783597253825

# %%
X_test.head(1)
# Out:
#             age  number_of_dependants  income_lakhs  insurance_plan  \
# 19713  0.652174                   0.0      0.262626             1.0
#
#        genetical_risk  normalized_risk_score  gender_Male  region_Northwest  \
# 19713             0.0               0.428571            0                 0
#
#        region_Southeast  region_Southwest  marital_status_Unmarried  \
# 19713                 0                 1                         1
#
#        bmi_category_Obesity  bmi_category_Overweight  \
# 19713                     0                        0
#
#        bmi_category_Underweight  smoking_status_Occasional  \
# 19713                         0                          0
#
#        smoking_status_Regular  employment_status_Salaried  \
# 19713                       0                           0
#
#        employment_status_Self-Employed
# 19713                                1

# %%
model_lr.intercept_
# Out:
# 5935.98128934458

# %%
# Let's now check the coefficient because that will help to interpret this model
model_lr.coef_
# Out:
# array([ 7.01623933e+03, -1.31176470e+03, -7.08193369e+02,  1.48359882e+04,
#         4.32009983e-12,  6.05362412e+03,  3.75582688e+01, -5.52508721e+01,
#        -1.96225429e+01, -2.22896756e+01, -7.00320200e+02,  3.92681271e+03,
#         1.97945605e+03,  6.12866236e+02,  8.37395101e+02,  2.80066184e+03,
#        -4.54913671e+01,  2.43078421e+02])

# %%
# In other model there is a method called model.feature_importances_ => it will tell us, how much important each of the features are 
# but in case of Linear Regression feature_importance is model_lr.coef_

# %%
feature_importance = pd.DataFrame({
    'Features': X_test.columns,
    'Importance': model_lr.coef_
})
# feature_importance
feature_importance_df = feature_importance.sort_values(by='Importance')
feature_importance_df.plot(x= 'Features', y= 'Importance', kind='barh')
plt.xlabel("Coefficient Value")
plt.title('Feature Importance in Linear Regression')
plt.show()

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Training Ridge Regression Model</h3>

# %%
model_ridge = Ridge(alpha=1)
model_ridge.fit(X_train, y_train)
train_score = model_ridge.score(X_train, y_train)
test_score = model_ridge.score(X_test, y_test)
train_score, test_score
# Out:
# (0.9534162332209687, 0.9538456995663842)

# %%
y_pred = model_ridge.predict(X_test)

mse_ridge = mean_squared_error(y_test, y_pred)
rmse_ridge = np.sqrt(mse_ridge)
print("Ridge Regression ==> MSE: ", mse_ridge, "RMSE: ", rmse_ridge)
# Out:
# Ridge Regression ==> MSE:  2183803.9339715624 RMSE:  1477.7699191591234

# %% [markdown]
# <h3 align="lest" style="color:darkorange">Training XGBoost Model</h3>

# %%
from xgboost import XGBRegressor
model_xgb = XGBRegressor()
model_xgb.fit(X_train, y_train)
train_score = model_xgb.score(X_train, y_train)
test_score = model_xgb.score(X_test, y_test)
train_score, test_score
# Out:
# (0.9986398939934333, 0.9979779802207822)

# %%
y_pred = model_xgb.predict(X_test)

mse_xgb = mean_squared_error(y_test, y_pred)
rmse_xgb = np.sqrt(mse_xgb)
print("XGBoost Regression ==> MSE: ", mse_xgb, "RMSE: ", rmse_xgb)
# Out:
# XGBoost Regression ==> MSE:  95672.44453797552 RMSE:  309.30962567947273

# %% [markdown]
# For furthur fine-tuning the model, and to select the best hyperparameter we can run GridSearchCv or RandomiseSearchCV

# %%
model_xgb = XGBRegressor()
param_grid = {
    'n_estimators': [20, 40, 50],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
}
random_search = RandomizedSearchCV(model_xgb, param_grid, n_iter=10, cv=3, scoring='r2', random_state=42, n_jobs=-1)
random_search.fit(X_train, y_train)
random_search.best_score_
# Out:
# 0.996737354697257

# %%
random_search.best_params_
# Out:
# {'n_estimators': 50, 'max_depth': 5, 'learning_rate': 0.1}

# %%
best_model = random_search.best_estimator_

# %%
feature_importance_xgb = pd.DataFrame({
    'Features': X_test.columns,
    'Importance': best_model.feature_importances_
})
feature_importance_xgb_df = feature_importance_xgb.sort_values(by='Importance')
feature_importance_xgb_df.plot(x= 'Features', y= 'Importance', kind='barh')
plt.xlabel("Importance")
plt.title('Feature Importance in XGBoost Regressor')
plt.show()

# %% [markdown]
# <h1 align="center" style="color:yellow">Error Analysis</h1>

# %%
y_pred = best_model.predict(X_test)
residuals = y_pred - y_test
residuals_pct = (residuals * 100)/y_test
results_df = pd.DataFrame({
    'actual': y_test,
    'predicted': y_pred,
    'diff': residuals,
    'diff_pct': residuals_pct
})
results_df.head()
# Out:
#        actual     predicted        diff  diff_pct
# 19713   26895  26585.556641 -309.443359 -1.150561
# 14750   22734  22588.554688 -145.445312 -0.639770
# 19932   21198  21517.458984  319.458984  1.507024
# 29643    9100   9312.083008  212.083008  2.330583
# 17076   26434  26585.556641  151.556641  0.573340

# %%
print(results_df.shape)
# Out:
# (8947, 4)

# %%
# It will be useful to look at the distribution and we use histogram (sns.histplot())

sns.histplot(data=results_df, x=results_df['diff_pct'], kde=True)
plt.show()

# %%
extreme_error_threshold = 10
extreme_results_df = results_df[abs(results_df['diff_pct']) > extreme_error_threshold]
extreme_results_df.shape
# Out:
# (22, 4)

# %%
results_df.shape
# Out:
# (8947, 4)

# %%
# We want to calculate percentage extreme error
extreme_error_pct = (extreme_results_df.shape[0] * 100) / results_df.shape[0]
extreme_error_pct
# Out:
# 0.24589247792556165

# %%
results_df[abs(results_df['diff_pct']) > 50].sort_values(by='diff_pct', ascending=False)
# Out:
# Empty DataFrame
# Columns: [actual, predicted, diff, diff_pct]
# Index: []

# %%
X_test.index
# Out:
# Index([19713, 14750, 19932, 29643, 17076, 20314, 24893, 26722, 25844, 10731,
#        ...
#        10637,  1224, 17046, 19228,  9275,  3387,  7858,  9744,  4849,  8986],
#       dtype='int64', length=8947)

# %%
extreme_results_df.index
# Out:
# Index([14286,  7547, 21910, 12189, 21141, 16263,  8216, 13973, 18522,  6163,
#        19145, 21455,  7508, 10741,  6517, 18834, 13744, 24119,  2695, 25658,
#        11019,  7654],
#       dtype='int64')

# %% [markdown]
# Since X_test.index and extreme_results_df.index values will be similar so using this extreme_results_df.index we need to look into X_test.index and figure out high margin errors  becuase we want to get the actual features

# %%
X_test.loc[extreme_results_df.index]
# Out:
#             age  number_of_dependants  income_lakhs  insurance_plan  \
# 14286  0.021739                   0.6      0.050505             0.0
# 7547   0.347826                   0.2      0.080808             0.0
# 21910  0.043478                   0.6      0.020202             0.0
# 12189  0.043478                   0.6      0.060606             0.0
# 21141  0.239130                   0.6      0.000000             0.0
# 16263  0.673913                   0.6      0.383838             0.0
# 8216   0.152174                   0.4      0.010101             0.0
# 13973  0.152174                   0.8      0.030303             0.0
# 18522  0.282609                   0.6      0.020202             0.0
# 6163   0.217391                   0.0      0.000000             0.0
# 19145  0.130435                   0.4      0.111111             0.0
# 21455  0.239130                   0.2      0.080808             0.0
# 7508   0.260870                   0.4      0.040404             0.0
# ...

# %%
extreme_errors_df = X_test.loc[extreme_results_df.index]
# extreme_errors_df.shape                               # this will same as X_test.shape
extreme_errors_df.head()
# Out:
#             age  number_of_dependants  income_lakhs  insurance_plan  \
# 14286  0.021739                   0.6      0.050505             0.0
# 7547   0.347826                   0.2      0.080808             0.0
# 21910  0.043478                   0.6      0.020202             0.0
# 12189  0.043478                   0.6      0.060606             0.0
# 21141  0.239130                   0.6      0.000000             0.0
#
#        genetical_risk  normalized_risk_score  gender_Male  region_Northwest  \
# 14286             0.0               0.000000            1                 1
# 7547              0.0               0.000000            1                 0
# 21910             0.0               0.000000            1                 0
# 12189             0.0               0.000000            1                 0
# 21141             0.0               0.857143            0                 0
#
#        region_Southeast  region_Southwest  marital_status_Unmarried  \
# ...

# %% [markdown]
# Since these features are scaled, just by looking at it, it's kind of hard to get understanding of it. For this we need to plot a distribution

# %%
sns.histplot(data=extreme_errors_df, x='income_lakhs', kde=True)
# Out:
# <Axes: xlabel='income_lakhs', ylabel='Count'>

# %%
for feature in X_test.columns:
    plt.figure(figsize=(10,4))
    sns.histplot(data=X_test, x=feature, color='blue', label='Overall', alpha=0.5, kde=True)
    sns.histplot(data=extreme_errors_df, x=feature, color='red', label='Extreme Errors', kde=True)
    plt.legend()
    plt.title(f"Distribution of {feature} for Extreme Errors VS Overall")
    plt.show()

# %%
sns.histplot(data= extreme_errors_df, x='age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %% [markdown]
# When i plot simple histogram with extreme_errors_df.age, we get this kind of ages because they are scaled, we can scale them back using the same scaler object

# %%
cols_to_scale
# Out:
# ['age',
#  'number_of_dependants',
#  'income_level',
#  'income_lakhs',
#  'insurance_plan',
#  'genetical_risk']

# %%
extreme_errors_df.columns
# Out:
# Index(['age', 'number_of_dependants', 'income_lakhs', 'insurance_plan',
#        'genetical_risk', 'normalized_risk_score', 'gender_Male',
#        'region_Northwest', 'region_Southeast', 'region_Southwest',
#        'marital_status_Unmarried', 'bmi_category_Obesity',
#        'bmi_category_Overweight', 'bmi_category_Underweight',
#        'smoking_status_Occasional', 'smoking_status_Regular',
#        'employment_status_Salaried', 'employment_status_Self-Employed'],
#       dtype='object')

# %%
extreme_errors_df['income_level'] = -1

# %%
df_reversed = pd.DataFrame()
df_reversed[cols_to_scale] = scaler.inverse_transform(extreme_errors_df[cols_to_scale])
df_reversed
# Out:
#      age  number_of_dependants  income_level  income_lakhs  insurance_plan  \
# 0   27.0                   3.0          -2.0           6.0             1.0
# 1   42.0                   1.0          -2.0           9.0             1.0
# 2   28.0                   3.0          -2.0           3.0             1.0
# 3   28.0                   3.0          -2.0           7.0             1.0
# 4   37.0                   3.0          -2.0           1.0             1.0
# 5   57.0                   3.0          -2.0          39.0             1.0
# 6   33.0                   2.0          -2.0           2.0             1.0
# 7   33.0                   4.0          -2.0           4.0             1.0
# 8   39.0                   3.0          -2.0           3.0             1.0
# 9   36.0                   0.0          -2.0           1.0             1.0
# 10  32.0                   2.0          -2.0          12.0             1.0
# ...

# %%
df_reversed = pd.DataFrame()
df_reversed[cols_to_scale] = scaler.inverse_transform(extreme_errors_df[cols_to_scale])
sns.histplot(df_reversed['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
df_reversed.describe()
# Out:
#              age  number_of_dependants  income_level  income_lakhs  \
# count  22.000000             22.000000          22.0     22.000000
# mean   36.136364              2.227273          -2.0      7.500000
# std     6.819408              1.151885           0.0      8.567658
# min    27.000000              0.000000          -2.0      1.000000
# 25%    32.250000              1.250000          -2.0      3.000000
# 50%    35.500000              2.500000          -2.0      5.000000
# 75%    39.750000              3.000000          -2.0      9.000000
# max    57.000000              4.000000          -2.0     39.000000
#
#        insurance_plan  genetical_risk
# count            22.0            22.0
# mean              1.0             0.0
# std               0.0             0.0
# min               1.0             0.0
# 25%               1.0             0.0
# 50%               1.0             0.0
# 75%               1.0             0.0
# max               1.0             0.0

# %% [markdown]
# <h1 align="center" style="color:yellow">Exporting the Model</h1>

# %%
from joblib import dump

dump(best_model, "artifacts/model_rest.joblib")

scaler_with_cols = {
    'scaler': scaler,
    'cols_to_scale': cols_to_scale
}

dump(scaler_with_cols, "artifacts/scaler_rest.joblib")
# Out:
# ['artifacts/scaler_rest.joblib']
